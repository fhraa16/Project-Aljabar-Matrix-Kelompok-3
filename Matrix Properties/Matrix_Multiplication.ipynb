# %% [markdown]
# ### 1. buat matrix A dengan ukuran 2x3 dan vector b berukuran 3x1

# %% [markdown]
# numpy

# %%
import numpy as np

# %%
A = np.array([[4, 5, 6], [7, 8, 9]])
A
# Out:
# array([[4, 5, 6],
#        [7, 8, 9]])

# %%
b = np.array([[3], [1], [4]])
b
# Out:
# array([[3],
#        [1],
#        [4]])

# %% [markdown]
# pytorch

# %%
import torch

# %%
A_pt = torch.tensor([[4, 5, 6], [7, 8, 9]])
A_pt
# Out:
# tensor([[4, 5, 6],
#         [7, 8, 9]])

# %%
b_pt = torch.tensor([[3], [1], [4]])
b_pt
# Out:
# tensor([[3],
#         [1],
#         [4]])

# %% [markdown]
# tensorflow

# %%
import tensorflow as tf

# %%
A_tf = tf.Variable([[4, 5, 6], [7, 8, 9]])
A_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[4, 5, 6],
#        [7, 8, 9]], dtype=int32)>

# %%
b_tf = tf.Variable([[3], [1], [4]])
b_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=int32, numpy=
# array([[3],
#        [1],
#        [4]], dtype=int32)>

# %% [markdown]
# ### 2.  tampilkan ukuran matrix A dan vector b

# %%
A.shape
# Out:
# (2, 3)

# %%
b.shape
# Out:
# (3, 1)

# %% [markdown]
# ### 3. kalikan matrix A dengan vector b

# %%
# numpy
np.dot(A, b)
# Out:
# array([[41],
#        [65]])

# %%
# pytorch
torch.matmul(A_pt, b_pt)
# Out:
# tensor([[41],
#         [65]])

# %%
# tensorflow
tf.matmul(A_tf, b_tf)
# Out:
# <tf.Tensor: shape=(2, 1), dtype=int32, numpy=
# array([[41],
#        [65]], dtype=int32)>

# %% [markdown]
# ### 4. buat matrix B dengan ukuran 3x3

# %%
# numpy
B = np.array([[4, 5, 8], [3, 5, 9], [3, 2, 9]])
B
# Out:
# array([[4, 5, 8],
#        [3, 5, 9],
#        [3, 2, 9]])

# %%
# pytorch
B_pt = torch.tensor([[4, 5, 8], [3, 5, 9], [3, 2, 9]])
B_pt
# Out:
# tensor([[4, 5, 8],
#         [3, 5, 9],
#         [3, 2, 9]])

# %%
# tensorflow
B_tf = tf.Variable([[4, 5, 8], [3, 5, 9], [3, 2, 9]])
B_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 3) dtype=int32, numpy=
# array([[4, 5, 8],
#        [3, 5, 9],
#        [3, 2, 9]], dtype=int32)>

# %% [markdown]
# ### 5. kalikan matrix A dengan matrix B

# %%
# numpy
np.dot(A, B)
# Out:
# array([[ 49,  57, 131],
#        [ 79,  93, 209]])

# %%
# pytorch
torch.matmul(A_pt, B_pt)
# Out:
# tensor([[ 49,  57, 131],
#         [ 79,  93, 209]])

# %%
# tensorflow
tf.matmul(A_tf, B_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[ 49,  57, 131],
#        [ 79,  93, 209]], dtype=int32)>

# %% [markdown]
# ### 6. buktikan apakah perkalian matrix bersifat komutatif? (AB=BA)?

# %%
AB = np.dot(A, B)
AB
# Out:
# array([[ 49,  57, 131],
#        [ 79,  93, 209]])

# %%
BA = np.dot(B, A)
BA
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_37978/1165396903.py in <cell line: 0>()
# ----> 1 BA = np.dot(B, A)
#       2 BA
#
# ValueError: shapes (3,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %% [markdown]
# disimpulkan bahwa perkalian matrix tidak bersifat komutatif
