# %% [markdown]
# 1. melakukan berbagai operasi yg dicontohkan menggunakan python

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 27

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 30

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x + y
sum = x + y
sum
# Out:
# 57

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 27.3

# %%
# jumlahkan x_float dengan y
sum = x_float + y
sum
# Out:
# 57.3

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_tf = tf.Variable(25)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=25>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_tf = tf.Variable(70)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=70>

# %%
# jumlahkan x + y
sum_tf = x_tf + y_tf
sum_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=95>

# %%
#  buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable(95.6)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=95.5999984741211>

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
# buat variabel x_pt dan suatu nilai tensor
x_pt = torch.tensor(70, dtype = torch.int32)
x_pt
# Out:
# tensor(70, dtype=torch.int32)

# %%
# tampilkan tipe data dari x_pt
x_pt = torch.tensor(88, dtype = torch.int32)
x_pt
# Out:
# tensor(88, dtype=torch.int32)

# %%
# buat variabel y_pt dan suatu nilai tensor
y_pt = torch.tensor(25, dtype = torch.int32)
y_pt
# Out:
# tensor(25, dtype=torch.int32)

# %%
# tampilkan tipe data dari y_pt
y_pt = torch.tensor(25, dtype = torch.int32)
y_pt
# Out:
# tensor(25, dtype=torch.int32)

# %%
# jumlahkan x_pt + y_pt
sum_pt = x_pt + y_pt
sum_pt
# Out:
# tensor(113, dtype=torch.int32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_pt_float = torch.tensor(27.3, dtype = torch.float32)
x_pt_float
# Out:
# tensor(27.3000)

# %%
# jumlahkan x_pt_float dengan y_pt
sum_pt = x_pt_float + y_pt
sum_pt
# Out:
# tensor(52.3000)

# %%
# tampilkan tipe data dari x_pt_float
x_pt_float = torch.tensor(27.3, dtype = torch.float32)
x_pt_float
# Out:
# tensor(27.3000)
