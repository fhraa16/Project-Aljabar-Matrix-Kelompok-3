# %% [markdown]
# 1.buat vector x dengan ukuran 3x1

# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([[10],
             [11],
             [58]])
x
# Out:
# array([[10],
#        [11],
#        [58]])

# %%
# hitung nilai L2 norm dari vector x
(10**2 + 11**2 + 58**2)**(1/2)
# Out:
# 59.87486951969081

# %% [markdown]
# 2. buat vector v dengan ukuran (3,4)

# %%
# buat vector v dengan elemen (3,4)
v = np.array([1, 70, 35])
v
# Out:
# array([ 1, 70, 35])

# %%
# hitung nilai L2 norm dari vector v
(1**2 + 70**2 + 35**2)**(1/2)
# Out:
# 78.26876771739798

# %%
# tampilkan unit vector dari vector v
norm = np.linalg.norm(x) # buat ngitung panjang vector
x_unit = x / norm # buat ngitung unit vector
x_unit
# Out:
# array([[0.16701498],
#        [0.18371648],
#        [0.96868687]])

# %%
# hitung panjang unit vector dari vector v
np.linalg.norm(x_unit)
# Out:
# np.float64(1.0)
